# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import regex as re

# %%
# 2. find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3. download html with a get request
response = requests.get(url)

# %%
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
#response.content

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
#soup

# %%
# 5. retrieve/extract the desired info (here, you'll paste the "Selector" you copied before to get the element that belongs to the top movie)
len(soup.select("body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper > div "))
#soup.select('#main > div > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid.ipc-page-grid--bias-left > div > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > div > div.ipc-title.ipc-title--base.ipc-title--title.ipc-title-link-no-icon.ipc-title--on-textPrimary.sc-b85248f1-7.lhgKeb.cli-title > a > h3')
#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn
# Out:
# 105

# %%
artist = []
song = []
genre = []
song_info = []

# for li in soup.select("body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper > div"):
    
#     song.append(li.select('cite.title').get_text())
#     for line in li.select('cite.title'):
#         song.append(line.get_text())
#     for line in li.select('em.artist'):
#         artist.append(line.get_text())
#     for line in li.select('strong.genre'):
#         genre.append(line.get_text())
# display(song)
# display(artist)

for song in soup.find_all('p', class_='title-artist'):
    song_name = song.find('cite', class_='title').get_text()
    artist_name = song.find('em', class_='artist').get_text()
    song_info.append((song_name, artist_name))
    
# for pr in soup.select("ul li a"):
#     link = pr.get("href")
#     print(link)

song_info
# Out:
# [('Lovin On Me', 'Jack Harlow'),
#  ('Lil Boo Thang', 'Paul Russell'),
#  ('White Horse', 'Chris Stapleton'),
#  ('I Remember Everything (feat. Kacey Musgraves)', 'Zach Bryan'),
#  ('Around Me the Cold Night', 'Luminara Stellaris'),
#  ('Need A Favor', 'Jelly Roll'),
#  ('Save Me (with Lainey Wilson)', 'Jelly Roll'),
#  ('90s Rap Mashup', 'Austin Williams'),
#  ('Next Winter I Will Wait for You Forever', 'Luminara Stellaris'),
#  ('Standing Next to You', 'Jung Kook'),
#  ('Cruel Summer', 'Taylor Swift'),
#  ('3D', 'Jung Kook & Jack Harlow'),
#  ('Even Though I Know You', 'Luminara Stellaris'),
#  ('Thinkin’ Bout Me', 'Morgan Wallen'),
#  ('All I Want for Christmas Is You', 'Mariah Carey'),
#  ('Christmas / Sarajevo 12/24 (Instrumental)', 'Trans-Siberian Orchestra'),
#  ('In the Sky a White Cloud Drifted Lazily', 'Luminara Stellaris'),
#  ('greedy', 'Tate McRae'),
#  ('Standing Next to You (Band Version)', 'Jung Kook'),
#  ('Fast Car', 'Luke Combs'),
#  ('Now And Then', 'The Beatles'),
#  ('Sin So Sweet', 'Warren Zeiders'),
#  ('Standing Next to You (Future Funk Remix)', 'Jung Kook'),
#  ('Standing Next to You (Slow Jam Remix)', 'Jung Kook'),
#  ('Standing Next to You (Holiday Remix)', 'Jung Kook'),
#  ('Standing Next to You (Instrumental)', 'Jung Kook'),
#  ('Lose Control', 'Teddy Swims'),
#  ('Standing Next to You (Latin Trap Remix)', 'Jung Kook'),
#  ('Standing Next to You (PBR&B Remix)', 'Jung Kook'),
#  ('Houdini', 'Dua Lipa'),
#  ('Water', 'Tyla'),
#  ("Now I Know I Know I've Lost You", 'Luminara Stellaris'),
#  ("Rockin' Around the Christmas Tree (Single)", 'Brenda Lee'),
#  ('Last Night', 'Morgan Wallen'),
#  ('Where the Wild Things Are', 'Luke Combs'),
#  ('The Wind Brings Winter', 'Luminara Stellaris'),
#  ('Paint The Town Red', 'Doja Cat'),
#  ('Fairytale Of Philadelphia',
#   'The Philly Specials, Jason Kelce & Travis Kelce'),
#  ('Still Not Fade the Footprints', 'Luminara Stellaris'),
#  ("Why Don't You Tell the Truth ?", 'The day you'),
#  ('Tonight I Dreamed a Pink Dream', 'Luminara Stellaris'),
#  ('Wrap Me Up', 'Jimmy Fallon & Meghan Trainor'),
#  ("You Don't Need to Worry", 'The day you'),
#  ('My Heart Has Come Back', 'Luminara Stellaris'),
#  ("Flyin' Pass (Single)", 'Caldwell'),
#  ('I Still Miss You Every Time Dusk Falls', 'Luminara Stellaris'),
#  ('If You Dont Have One-The Day You', 'The day you'),
#  ('The Pink Rays of Sunlight Disappear', 'Luminara Stellaris'),
#  ('Rich Men North of Richmond', 'Oliver Anthony Music'),
#  ('The Buds of Youth Are Still Lingering There', 'Luminara Stellaris'),
#  ('Weather Forecast Today Rain', 'The day you'),
#  ('To Be A Man (feat. Darius Rucker)', 'Dax'),
#  ('Can’t Catch Me Now (from The Hunger Games: The Ballad of Songbirds & Snakes)',
#   'Olivia Rodrigo'),
#  ('Better Place (From TROLLS Band Together)', '*NSYNC & Justin Timberlake'),
#  ('Wild Ones (Extended Version)', 'Jessie Murph & Jelly Roll'),
#  ('Karma', 'Taylor Swift'),
#  ('Used To Be Young', 'Miley Cyrus'),
#  ('Evil Ways (feat. J. Cole)', 'Drake'),
#  ('Forever Settled Inside Me', 'Luminara Stellaris'),
#  ('Snowman', 'Sia'),
#  ('Save Me', 'Jelly Roll'),
#  ('My Arms Are Spread Wide With Joy', 'Luminara Stellaris'),
#  ("So It's Sad to Be Apart", 'Luminara Stellaris'),
#  ("Please Stay Don't Go", 'The day you'),
#  ('Fancy Like Christmas', 'Walker Hayes'),
#  ('Seven (Explicit Ver.)', 'Jung Kook & Latto'),
#  ('The Christmas Song (Merry Christmas to You)', 'Nat "King" Cole'),
#  ('You Broke My Heart', 'Drake'),
#  ('exes', 'Tate McRae'),
#  ('Watermelon Moonshine', 'Lainey Wilson'),
#  ('MONACO', 'Bad Bunny'),
#  ('Islands In the Stream', 'Dolly Parton & Kenny Rogers'),
#  ('Anti-Hero', 'Taylor Swift'),
#  ('The Painter', 'Cody Johnson'),
#  ("Is It Over Now? (Taylor's Version) [From The Vault]", 'Taylor Swift'),
#  ('Those Who Leave Will Not Return', 'Luminara Stellaris'),
#  ('Tennessee Whiskey', 'Chris Stapleton'),
#  ('Lover', 'Taylor Swift'),
#  ('Son Of A Sinner', 'Jelly Roll'),
#  ('Dance The Night', 'Dua Lipa'),
#  ('Gratitude', 'Brandon Lake'),
#  ('Autumn Comes Dry', 'Luminara Stellaris'),
#  ('Wizards in Winter (Instrumental)', 'Trans-Siberian Orchestra'),
#  ('Bigger Than The Whole Sky', 'Taylor Swift'),
#  ('What Was I Made For? [From The Motion Picture "Barbie"]', 'Billie Eilish'),
#  ("The Chipmunk Song (Christmas Don't Be Late)", 'Alvin & The Chipmunks'),
#  ('See You in Another Time', 'The day you'),
#  ("Stay With Me Santa (Mrs. Claus' Christmas Wish)", 'SMITH'),
#  ('Missing the Fragrant Afternoon', 'Luminara Stellaris'),
#  ('I Hold the Storm in My Heart', 'The day you'),
#  ('Daylight', 'David Kushner'),
#  ('Keith', 'Kaylee Bell'),
#  ('TRUCK BED', 'HARDY'),
#  ('White Christmas', 'Bing Crosby'),
#  ('Flowers', 'Miley Cyrus'),
#  ('vampire', 'Olivia Rodrigo'),
#  ('Pretty Little Poison', 'Warren Zeiders'),
#  ('Presha', '2 Chainz & Lil Wayne'),
#  ('Strangers', 'Kenya Grace'),
#  ('G6', '2 Chainz & Lil Wayne')]

# %%
# each list becomes a column
top_100 = pd.DataFrame(song_info, columns=['Song', 'Artist'])

top_100
# Out:
#                                              Song                Artist
# 0                                     Lovin On Me           Jack Harlow
# 1                                   Lil Boo Thang          Paul Russell
# 2                                     White Horse       Chris Stapleton
# 3   I Remember Everything (feat. Kacey Musgraves)            Zach Bryan
# 4                        Around Me the Cold Night    Luminara Stellaris
# ..                                            ...                   ...
# 95                                        vampire        Olivia Rodrigo
# 96                           Pretty Little Poison        Warren Zeiders
# 97                                         Presha  2 Chainz & Lil Wayne
# 98                                      Strangers           Kenya Grace
# 99                                             G6  2 Chainz & Lil Wayne
#
# [100 rows x 2 columns]

# %%
url = "https://www.popvortex.com/music/charts/top-100-albums.php"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
artist = []
album = []
album_info = []

for album in soup.find_all('p', class_='title-artist'):
    album_name = album.find('cite', class_='title').get_text()
    artist_name = album.find('em', class_='artist').get_text()
    album_info.append((album_name, artist_name))

# %%
# each list becomes a column
top_album = pd.DataFrame(album_info, columns=['Song', 'Artist'])

top_album
# Out:
#                                                  Song  \
# 0                                            Rockstar
# 1                                        New Blue Sun
# 2                                              Higher
# 3                                               Cosmo
# 4                                Welcome 2 Collegrove
# ..                                                ...
# 95                             Alone at Prom (Deluxe)
# 96  Nerdy Prudes Must Die (Original StarKid Cast R...
# 97                                      Super Natural
# 98  THE BOYZ 2ND ALBUM [PHANTASY] Pt. 2 Sixth Sens...
# 99                                          Metallica
#
#                                             Artist
# 0                                     Dolly Parton
# 1                                       André 3000
# 2                                  Chris Stapleton
# 3                                            Ozuna
# 4                             2 Chainz & Lil Wayne
# ..                                             ...
# 95                                      Tory Lanez
# 96  Original StarKid Cast of Nerdy Prudes Must Die
# 97                                 The Wilder Blue
# 98                                        THE BOYZ
# 99                                       Metallica
#
# [100 rows x 2 columns]

# %%
####post-1479786 > div.pmc-paywall > div > div > div > div.chart-results-list.\/\/.lrv-u-padding-t-150.lrv-u-padding-t-050\@mobile-max > div.o-chart-results-list-row-container.u-box-shadow-header-main.lrv-u-position-relative.u-z-index-middle-bottom > ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.u-border-b-0\@mobile-max.lrv-u-border-color-grey-light.lrv-u-padding-l-1\@mobile-max

# %%
# url = "https://www.billboard.com/charts/hot-100/"
# response = requests.get(url)

# %%
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# ### Wikipedia - List of Songs Recorded by Maroon 5

# %%
url = "https://en.wikipedia.org/wiki/List_of_songs_recorded_by_Maroon_5"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
#soup

# %%
table = soup.find('table', class_='wikitable')
#print(table)

# %%
# Iterate through rows in the table
maroon5_songs = []

for row in table.find_all('tr')[1:]:
    columns = row.find_all(['td','th'])
    maroon5_songs.append(columns[0].text.strip().replace('\'','').replace('"',''))

maroon5_songs
maroon5 = pd.DataFrame({'Song':maroon5_songs, 'Artist':'Maroon 5'})
maroon5
# Out:
#                                                   Song    Artist
# 0                                              Animals  Maroon 5
# 1                                    Back At Your Door  Maroon 5
# 2                                    Beautiful Goodbye  Maroon 5
# 3    Beautiful Mistakes (featuring Megan Thee Stall...  Maroon 5
# 4                                 Better That We Break  Maroon 5
# ..                                                 ...       ...
# 103                    Whiskey  (featuring ASAP Rocky)  Maroon 5
# 104             Who I Am  (featuring LunchMoney Lewis)  Maroon 5
# 105                                     Wipe Your Eyes  Maroon 5
# 106                                              Woman  Maroon 5
# 107                           Wont Go Home Without You  Maroon 5
#
# [108 rows x 2 columns]

# %% [markdown]
# ### Wikipedia - List of Most Streamed Songs in the UK

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-streamed_songs_in_the_United_Kingdom"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find('table', class_='wikitable')

# %%
songs = []
uk_artists = []
row_count = 0 

#the table has a non-conforming last row with comments. So using row-count variable to hit till the end
#which using trial and error found it as 48. 15 and 16 is missing from the table in wiki

for row in table.find_all('tr')[1:]:
    columns = row.find_all(['td','th'])
    songs.append(columns[1].text.strip().replace('"', ''))
    uk_artists.append(columns[2].text.strip())
    
    row_count+=1
    if row_count >= 48 :
        break
#songs = songs.to_str.replace('"','')
uk_songs = pd.DataFrame({'Song':songs, 'Artist':uk_artists})
#uk_songs
# Out:
#                                          Song  \
# 0                           Someone You Loved
# 1                                Shape of You
# 2   Perfect / Perfect Duet / Perfect Symphony
# 3                                     Shotgun
# 4                                Dance Monkey
# 5                             Blinding Lights
# 6                              Mr. Brightside
# 7                                  Baby Shark
# 8                Despacito /Despacito (Remix)
# 9                                     Shallow
# 10                              Old Town Road
# 11                       Say You Won't Let Go
# 12                          Thinking Out Loud
# 13                                 Bad Habits
# 14                                  One Dance
# 15                         Castle on the Hill
# 16                                   One Kiss
# 17                                    Bad Guy
# 18            All I Want for Christmas Is You
# 19                               I Don't Care
# 20                                  New Rules
# 21                                    Riptide
# 22                               Head & Heart
# 23                             Girls Like You
# 24                           Sweet but Psycho
# 25                                 Wonderwall
# 26                                 This Is Me
# 27                                    Bruises
# 28                             Last Christmas
# 29                                 These Days
# 30                                   Location
# 31                                   Eastside
# 32                                 God's Plan
# 33                                  All of Me
# 34                              Cheap Thrills
# 35                                   Rockstar
# 36                                Uptown Funk
# 37                            Don't Start Now
# 38                                     Havana
# 39                              Before You Go
# 40                               Lucid Dreams
# 41                          Take Me to Church
# 42                    Can't Stop the Feeling!
# 43                                  Vossi Bop
# 44                                 Photograph
# 45                                      Sorry
# 46                                     Closer
# 47                           Do I Wanna Know?
#
#                                                Artist
# 0                                       Lewis Capaldi
# 1                                          Ed Sheeran
# 2   Ed Sheeran / Ed Sheeran featuring Beyoncé / Ed...
# 3                                         George Ezra
# 4                                         Tones and I
# 5                                          The Weeknd
# 6                                         The Killers
# 7                                            Pinkfong
# 8   Luis Fonsi featuring Daddy Yankee / Luis Fonsi...
# 9                        Lady Gaga and Bradley Cooper
# 10                                          Lil Nas X
# 11                                       James Arthur
# 12                                         Ed Sheeran
# 13                                         Ed Sheeran
# 14                    Drake featuring Wizkid and Kyla
# 15                                         Ed Sheeran
# 16                   Calvin Harris featuring Dua Lipa
# 17                                      Billie Eilish
# 18                                       Mariah Carey
# 19                       Ed Sheeran and Justin Bieber
# 20                                           Dua Lipa
# 21                                          Vance Joy
# 22                          Joel Corry featuring MNEK
# 23                         Maroon 5 featuring Cardi B
# 24                                            Ava Max
# 25                                              Oasis
# 26     Keala Settle and The Greatest Showman Ensemble
# 27                                      Lewis Capaldi
# 28                                              Wham!
# 29  Rudimental featuring Jess Glynne, Macklemore, ...
# 30                           Dave featuring Burna Boy
# 31                    Benny Blanco, Halsey and Khalid
# 32                                              Drake
# 33                                        John Legend
# 34                            Sia featuring Sean Paul
# 35                                        Post Malone
# 36                   Mark Ronson featuring Bruno Mars
# 37                                           Dua Lipa
# 38                Camila Cabello featuring Young Thug
# 39                                      Lewis Capaldi
# 40                                         Juice Wrld
# 41                                             Hozier
# 42                                  Justin Timberlake
# 43                                            Stormzy
# 44                                         Ed Sheeran
# 45                                      Justin Bieber
# 46                  The Chainsmokers featuring Halsey
# 47                                     Arctic Monkeys

# %%
top_songs = pd.concat([top_100, maroon5, uk_songs])
top_songs.shape
# Out:
# (256, 2)

# %%
top_songs = top_songs.reset_index()
top_songs = top_songs.drop('index', axis=1)
top_songs.tail()
# Out:
#                  Song                             Artist
# 251         Vossi Bop                            Stormzy
# 252        Photograph                         Ed Sheeran
# 253             Sorry                      Justin Bieber
# 254            Closer  The Chainsmokers featuring Halsey
# 255  Do I Wanna Know?                     Arctic Monkeys

# %%
top_songs.shape
# Out:
# (256, 2)

# %% [markdown]
# ### Song Recommender First Iteration
# - Ask for user input
# - If song present in the list, then recommend another song from the list
# - If not, a polite message

# %%
# Getting all lower str
top_songs_lower = top_songs.apply(lambda x: x.astype(str).str.lower())
top_songs_lower['Song'] = top_songs_lower['Song'].apply(remove_special_characters)
top_songs_lower
# Out:
#                                            Song  \
# 0                                   lovin on me
# 1                                 lil boo thang
# 2                                   white horse
# 3    i remember everything feat kacey musgraves
# 4                      around me the cold night
# ..                                          ...
# 251                                   vossi bop
# 252                                  photograph
# 253                                       sorry
# 254                                      closer
# 255                             do i wanna know
#
#                                 Artist
# 0                          jack harlow
# 1                         paul russell
# 2                      chris stapleton
# 3                           zach bryan
# 4                   luminara stellaris
# ..                                 ...
# 251                            stormzy
# 252                         ed sheeran
# 253                      justin bieber
# 254  the chainsmokers featuring halsey
# 255                     arctic monkeys
#
# [256 rows x 2 columns]

# %%
def song_recommender(title, artist):
    #Convert the input to lower case
    title_input = remove_special_characters(title.lower())
    artist_input = remove_special_characters(artist.lower())
    
    # Check if the input combination is present in the dataframe
    result = top_songs_lower[(top_songs_lower['Song'].values == title_input) & (top_songs_lower['Artist'].values == artist_input)]
    #print(result)

    if not result.empty:
        #Get the indices
        indices_to_remove = result.index
        temp_top_songs = top_songs.drop(indices_to_remove)

        rec_song = temp_top_songs.sample().squeeze()
        print(f"You might also like: {rec_song['Song']} by {rec_song['Artist']}")
    else:
        print('We are sorry but we cannot provide a recommendation right now. We are working on it!')

def remove_special_characters(text):
    # Use a regular expression to replace non-alphanumeric characters with an empty string
    return ''.join(e for e in text if e.isalnum() or e.isspace())

# %%
#Get user input
title_input = input('Please Enter the Song Title: ')
artist_input = input('Please Enter the Artist Name: ')
song_recommender(title_input, artist_input)
# Out:
# Please Enter the Song Title: photograph
# Please Enter the Artist Name: ed sheeran
# You might also like: No Curtain Call by Maroon 5
